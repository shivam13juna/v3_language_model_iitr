# %%
#docker run -d \
#  --name chroma \
#  -p 8001:8000 \
#  -v chroma_data:/data \
#  -e IS_PERSISTENT=TRUE \
#  -e PERSIST_DIRECTORY=/data \
#  -e ANONYMIZED_TELEMETRY=FALSE \
#  chromadb/chroma:1.0.15
